# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

# %%
X_train = pd.read_csv('/t2-2-X_train.csv')
test = pd.read_csv('/t2-2-X_test.csv')
y_train = pd.read_csv('/t2-2-y_train.csv')

# %%
from sklearn.model_selection import train_test_split

X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, train_size = 0.8)

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()
model.fit(X_train, y_train)
y_pred = model.predict(X_valid)

# %%
from sklearn.metrics import *
r2_score(y_valid, y_pred)
# Out:
# 0.8582237816143545

# %%
pred = model.predict(test)

# %%
new_df = test['Serial No.']

# %%
new_df['Chance of Admit'] = pred
# Out:
# <ipython-input-41-a20531f59181>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Chance of Admit'] = pred

# %%
new_df.to_csv('/content/drive/MyDrive/Colab Notebooks/sub.csv', index = False)
